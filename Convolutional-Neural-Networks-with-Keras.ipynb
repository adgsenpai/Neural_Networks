# %% [markdown]
# We will learn how to use the Keras library to build convolutional neural networks. We will also use the popular MNIST dataset and we will compare our results to using a conventional neural network.

# %% [markdown]
# <h2>Convolutional Neural Networks with Keras</h2>
#
# <h3>Objective for this Notebook<h3>
# <h5> 1. How to use the Keras library to build convolutional neural networks.</h5>
# <h5> 2. Convolutional Neural Network with One Convolutional and Pooling Layers.</h5>
# <h5> 3. Convolutional Neural Network with Two Convolutional and Pooling Layers.</h5>

# %% [markdown]
# ## Import Keras and Packages

# %% [markdown]
# Let's start by importing the keras libraries and the packages that we would need to build a neural network.

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# When working with convolutional neural networks in particular, we will need additional packages.

# %%
from keras.layers.convolutional import Conv2D # to add convolutional layers
from keras.layers.convolutional import MaxPooling2D # to add pooling layers
from keras.layers import Flatten # to flatten data for fully connected layers

# %% [markdown]
# <a id='item42'></a>

# %% [markdown]
# ## Convolutional Layer with One set of convolutional and pooling layers

# %%
# import data
from keras.datasets import mnist

# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# %% [markdown]
# Let's normalize the pixel values to be between 0 and 1

# %%
X_train = X_train / 255 # normalize training data
X_test = X_test / 255 # normalize test data

# %% [markdown]
# Next, let's convert the target variable into binary categories

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1] # number of categories

# %% [markdown]
# Next, let's define a function that creates our model. Let's start with one set of convolutional and pooling layers.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Conv2D(16, (5, 5), strides=(1, 1), activation='relu', input_shape=(28, 28, 1)))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Finally, let's call the function to create the model, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 9s - loss: 0.2819 - accuracy: 0.9241 - val_loss: 0.0948 - val_accuracy: 0.9709
# Epoch 2/10
# 300/300 - 9s - loss: 0.0797 - accuracy: 0.9769 - val_loss: 0.0633 - val_accuracy: 0.9813
# Epoch 3/10
# 300/300 - 7s - loss: 0.0556 - accuracy: 0.9835 - val_loss: 0.0499 - val_accuracy: 0.9838
# Epoch 4/10
# 300/300 - 8s - loss: 0.0426 - accuracy: 0.9871 - val_loss: 0.0557 - val_accuracy: 0.9805
# Epoch 5/10
# 300/300 - 7s - loss: 0.0338 - accuracy: 0.9899 - val_loss: 0.0395 - val_accuracy: 0.9865
# Epoch 6/10
# 300/300 - 7s - loss: 0.0289 - accuracy: 0.9909 - val_loss: 0.0337 - val_accuracy: 0.9884
# Epoch 7/10
# 300/300 - 7s - loss: 0.0229 - accuracy: 0.9930 - val_loss: 0.0361 - val_accuracy: 0.9881
# Epoch 8/10
# 300/300 - 6s - loss: 0.0195 - accuracy: 0.9938 - val_loss: 0.0359 - val_accuracy: 0.9882
# Epoch 9/10
# 300/300 - 7s - loss: 0.0162 - accuracy: 0.9951 - val_loss: 0.0481 - val_accuracy: 0.9852
# Epoch 10/10
# 300/300 - 6s - loss: 0.0140 - accuracy: 0.9958 - val_loss: 0.0364 - val_accuracy: 0.9882
# Accuracy: 0.9882000088691711
#  Error: 1.1799991130828857

# %% [markdown]
# ## Convolutional Layer with two sets of convolutional and pooling layers

# %% [markdown]
# Let's redefine our convolutional model so that it has two convolutional and pooling layers instead of just one layer of each.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Conv2D(16, (5, 5), activation='relu', input_shape=(28, 28, 1)))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Conv2D(8, (2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # Compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Now, let's call the function to create our new convolutional neural network, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 10s - loss: 0.5121 - accuracy: 0.8492 - val_loss: 0.1682 - val_accuracy: 0.9524
# Epoch 2/10
# 300/300 - 8s - loss: 0.1355 - accuracy: 0.9596 - val_loss: 0.1000 - val_accuracy: 0.9688
# Epoch 3/10
# 300/300 - 8s - loss: 0.0908 - accuracy: 0.9729 - val_loss: 0.0684 - val_accuracy: 0.9785
# Epoch 4/10
# 300/300 - 8s - loss: 0.0705 - accuracy: 0.9783 - val_loss: 0.0546 - val_accuracy: 0.9829
# Epoch 5/10
# 300/300 - 9s - loss: 0.0594 - accuracy: 0.9821 - val_loss: 0.0479 - val_accuracy: 0.9854
# Epoch 6/10
# 300/300 - 9s - loss: 0.0511 - accuracy: 0.9843 - val_loss: 0.0419 - val_accuracy: 0.9871
# Epoch 7/10
# 300/300 - 9s - loss: 0.0445 - accuracy: 0.9865 - val_loss: 0.0397 - val_accuracy: 0.9874
# Epoch 8/10
# 300/300 - 9s - loss: 0.0398 - accuracy: 0.9879 - val_loss: 0.0366 - val_accuracy: 0.9883
# Epoch 9/10
# 300/300 - 10s - loss: 0.0349 - accuracy: 0.9893 - val_loss: 0.0320 - val_accuracy: 0.9898
# Epoch 10/10
# 300/300 - 9s - loss: 0.0314 - accuracy: 0.9905 - val_loss: 0.0350 - val_accuracy: 0.9883
# Accuracy: 0.9883000254631042
#  Error: 1.1699974536895752
